# %%
import pandas as pd
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"/Users/mac/Downloads/2026-sp.csv")
df
# Out:
#        Year    Term YearTerm Subject  Number                          Name  \
# 0      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# 1      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# 2      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# 3      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# 4      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 12210  2026  Spring  2026-sp    WRIT     300    Issues in Tutoring Writing
# 12211  2026  Spring  2026-sp    WRIT     303          Writing Across Media
# 12212  2026  Spring  2026-sp    WRIT     303          Writing Across Media
# 12213  2026  Spring  2026-sp    WRIT     303          Writing Across Media
# 12214  2026  Spring  2026-sp    WRIT     303          Writing Across Media
#
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#        Year    Term YearTerm Subject  Number                          Name  \
# 0      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# 1      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# 2      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# 3      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# 4      2026  Spring  2026-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 12210  2026  Spring  2026-sp    WRIT     300    Issues in Tutoring Writing
# 12211  2026  Spring  2026-sp    WRIT     303          Writing Across Media
# 12212  2026  Spring  2026-sp    WRIT     303          Writing Across Media
# 12213  2026  Spring  2026-sp    WRIT     303          Writing Across Media
# 12214  2026  Spring  2026-sp    WRIT     303          Writing Across Media
#
# ...

# %%
df = df.drop(columns = ["Description", "YearTerm", "Schedule Information", "Section Info", "Status Code", "Section Credit Hours", "Enrollment Status", "Name", "Section Title", "Section Status", "Type"])
df
# Out:
#        Year    Term Subject  Number Credit Hours  \
# 0      2026  Spring     AAS     100     3 hours.
# 1      2026  Spring     AAS     100     3 hours.
# 2      2026  Spring     AAS     100     3 hours.
# 3      2026  Spring     AAS     100     3 hours.
# 4      2026  Spring     AAS     100     3 hours.
# ...     ...     ...     ...     ...          ...
# 12210  2026  Spring    WRIT     300     3 hours.
# 12211  2026  Spring    WRIT     303     3 hours.
# 12212  2026  Spring    WRIT     303     3 hours.
# 12213  2026  Spring    WRIT     303     3 hours.
# 12214  2026  Spring    WRIT     303     3 hours.
#
#                                        Degree Attributes    CRN Section  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  30107     AD1
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  41729     AD2
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  43832     AD3
# 3      Social & Beh Sci - Soc Sci, and Cultural Studi...  48232     AD4
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Year    Term Subject  Number Credit Hours  \
# 0      2026  Spring     AAS     100     3 hours.
# 1      2026  Spring     AAS     100     3 hours.
# 2      2026  Spring     AAS     100     3 hours.
# 3      2026  Spring     AAS     100     3 hours.
# 4      2026  Spring     AAS     100     3 hours.
# ...     ...     ...     ...     ...          ...
# 12210  2026  Spring    WRIT     300     3 hours.
# 12211  2026  Spring    WRIT     303     3 hours.
# 12212  2026  Spring    WRIT     303     3 hours.
# 12213  2026  Spring    WRIT     303     3 hours.
# 12214  2026  Spring    WRIT     303     3 hours.
#
#                                        Degree Attributes    CRN Section  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  30107     AD1
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  41729     AD2
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  43832     AD3
# ...
